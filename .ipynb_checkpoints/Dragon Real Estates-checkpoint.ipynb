# %% [markdown]
# ## Dragon Real Estate -Price predictor

# %%
import pandas as pd

# %%
housing=pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
housing['CHAS'].value_counts()
# Out:
# CHAS
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
#for ploting

# %%
housing.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Train Test Split

# %%
 import numpy as np
#for learning
def split_train_test(data,test_ratio):
    np.random.seed(42)
    shuffled=np.random.permutation(len(data))
    #print(shuffled)
    test_set_size=int(len(data)*test_ratio)
    test_indices=shuffled[:test_set_size]
    train_indices=shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
# train_set, test_set=split_train_test(housing,0.2)

# %%
# print(f"Rows in train set: {len(train_set)}\n Rows in test set: {len(test_set)}\n")

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)
print(f"Rows in train set: {len(train_set)}\n Rows in test set: {len(test_set)}\n")
# Out:
# Rows in train set: 404
#  Rows in test set: 102

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean     3.655942   13.450980   10.312255    0.068627    0.541353    6.303353
# std     10.400966   27.503241    6.761154    0.254068    0.111397    0.662996
# min      0.009060    0.000000    0.460000    0.000000    0.385000    4.138000
# 25%      0.057827    0.000000    4.950000    0.000000    0.448000    5.912750
# 50%      0.176150    0.000000    7.760000    0.000000    0.515000    6.176000
# 75%      2.061955    0.000000   18.100000    0.000000    0.612750    6.539500
# max     88.976200   90.000000   27.740000    1.000000    0.871000    8.725000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  102.000000  102.000000  102.000000  102.000000  102.000000  102.000000
# mean    66.733333    3.988460    8.813725  391.980392   18.385294  369.670196
# ...

# %%
strat_test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 342 to 218
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     102 non-null    float64
#  1   ZN       102 non-null    float64
#  2   INDUS    102 non-null    float64
#  3   CHAS     102 non-null    int64
#  4   NOX      102 non-null    float64
#  5   RM       102 non-null    float64
#  6   AGE      102 non-null    float64
#  7   DIS      102 non-null    float64
#  8   RAD      102 non-null    int64
#  9   TAX      102 non-null    int64
#  10  PTRATIO  102 non-null    float64
#  11  B        102 non-null    float64
#  12  LSTAT    102 non-null    float64
#  13  MEDV     102 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 12.0 KB

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    95
# 1     7
# Name: count, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
95/7
# Out:
# 13.571428571428571

# %%
376/28
# Out:
# 13.428571428571429

# %%
housing=strat_train_set.copy()

# %% [markdown]
# ## looking for Correlations

# %%
corr_matrix=housing.corr()
#to identify if one increse what effect other
#1 stprng postive correlation

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680857
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes=["MEDV","RM","ZN","LSTAT"]
#checking corrlation for few  elements 
scatter_matrix(housing[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
housing.plot(kind="scatter",x="RM",y="MEDV",alpha=0.9)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ##  trying out Attribute combinations

# %%
#TAXRM=tax per room ctraeting new Attributr
housing["TAXRM"]=housing['TAX']/housing['RM']

# %%
housing["TAXRM"]
# Out:
# 254     51.571709
# 348     42.200452
# 476    102.714374
# 321     45.012547
# 326     45.468948
#           ...
# 155     65.507152
# 423    109.126659
# 98      35.294118
# 455    102.068966
# 216     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
housing.head()
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254  0.04819  80.0   3.64     0  0.392  6.108  32.0  9.2203    1  315
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 476  4.87141   0.0  18.10     0  0.614  6.484  93.6  2.3053   24  666
# 321  0.18159   0.0   7.38     0  0.493  6.376  54.3  4.5404    5  287
# 326  0.30347   0.0   7.38     0  0.493  6.312  28.9  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV       TAXRM
# 254     16.4  392.89   6.57  21.9   51.571709
# 348     17.0  390.94   5.99  24.5   42.200452
# 476     20.2  396.21  18.68  16.7  102.714374
# 321     19.6  396.90   6.87  23.1   45.012547
# 326     19.6  396.90   6.15  23.0   45.468948

# %%
corr_matrix=housing.corr()
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV       1.000000
# RM         0.680857
# B          0.361761
# ZN         0.339741
# DIS        0.240451
# CHAS       0.205066
# AGE       -0.364596
# RAD       -0.374693
# CRIM      -0.393715
# NOX       -0.422873
# TAX       -0.456657
# INDUS     -0.473516
# PTRATIO   -0.493534
# TAXRM     -0.528626
# LSTAT     -0.740494
# Name: MEDV, dtype: float64

# %%
  housing.plot(kind="scatter",x="TAXRM",y="MEDV",alpha=0.9)
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
housing=strat_train_set.drop("MEDV",axis=1)
#one colum TAXRM i added for demo now i removed it
housing_labels=strat_train_set["MEDV"].copy()
#housing_labels is my train data

# %% [markdown]
# ## Missing  Attributes

# %%
# to take care of missing attribues ,you have three options
# 1.get rid of the missing data points
# 2.get rid of the whole attribute
# 3.set the value to some(0,mean,meadin)

# %%
# a=housing.dropna(subset=["RM"] # option1
#              a.shape
# orignal housing not changing until i set TRUE

# %%
# housing.drop("RM",axis=1) #option2
 # RM colum removed   

# orignal housing not changing until i set TRUE

# %%
#  median=housing["RM"].medain() #option 3 replace to medain
# housing["RM"].fillna(median)
# orignal housing not changing until i set TRUE

# %%
housing.describe()  #before we satrted filling missing attributes
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  399.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.279481
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.716784
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.876500
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %%
from sklearn.impute import SimpleImputer

# Assuming you want to use the median strategy
imputer = SimpleImputer(strategy="median")
imputer.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.86735e-01, 0.00000e+00, 9.90000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.82000e+01, 3.12220e+00, 5.00000e+00, 3.37000e+02,
#        1.90000e+01, 3.90955e+02, 1.15700e+01])

# %%
X=imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(X, columns=housing.columns)
##creating new dataframe for demo

# %%
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.602814   10.836634   11.344950    0.069307    0.558064    6.278609
# std      8.099383   22.150636    6.877817    0.254290    0.116875    0.712366
# min      0.006320    0.000000    0.740000    0.000000    0.389000    3.561000
# 25%      0.086962    0.000000    5.190000    0.000000    0.453000    5.878750
# 50%      0.286735    0.000000    9.900000    0.000000    0.538000    6.209000
# 75%      3.731923   12.500000   18.100000    0.000000    0.631000    6.630000
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.039851    3.746210    9.735149  412.341584   18.473267  353.392822
# ...

# %% [markdown]
# ##  scikit-learn desgin

# %%
# Primarily ,three types of objects
# 1
# estimators-It estimates some parameters on a dataset example imputer it has a fit and transform method
# fit method-fits the dataset and calculates internal parameters
# 2
# transformers-transform takes inputs and returns output based on the leraning from fit(). it also has a convenience function called fit_transform() which fit and then transform.
# 3
# predictors- LinearRegression,model is an example of predictor . fit and predict are two common functions. it also gives spme score functions which will evaluate the predictions

# %% [markdown]
#  ## Feature Scaling

# %%
#  Primarily, two types of feature scalling:
# 1
# Min-max scalling(Normalizatio)
#    (value-min)/(max-min)
#     Sklearn provides a class called MinMaxScaler for this


# 2 Standrization 
#    (value-mean)/standerd daviation
# sklearn provides  a class called standard Scalar for this

# %% [markdown]
# ## Creating a Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# Define your pipeline steps it takes list
my_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('std_scalar', StandardScaler())
])

# %%
housing_num_tr=my_pipeline.fit_transform(housing)

# %%
housing_num_tr
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %%
housing_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
#  ## selecting a desired model for Dragon Real Estates

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

#model = LinearRegression()
#model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]

# %%
some_labels=housing_labels.iloc[:5]

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([22.434, 25.15 , 16.265, 23.244, 23.64 ])

# %%
list(some_labels)
# Out:
# [21.9, 24.5, 16.7, 23.1, 23.0]

# %% [markdown]
# ## Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

housing_predictions = model.predict(housing_num_tr)
mse = mean_squared_error(housing_labels, housing_predictions)

# RMSE (root mean squared error)
lin_rmse = np.sqrt(mse)

#rmse=root of mean squre error

# %%
lin_rmse
# Out:
# 1.1785953955601731

# %% [markdown]
#  ## Using better evalution techinque  Cross validation

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

# Assuming `model`, `housing_num_tr`, and `housing_labels` are defined
# cv is cross validation score ex  the data will be divided into 5 equal parts, and the model will be trained and evaluated 5 time
scores = cross_val_score(model, housing_num_tr, housing_labels, scoring="neg_mean_squared_error", cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([2.87180099, 2.53708126, 4.50680799, 2.58460539, 3.33792701,
#        2.66122177, 4.86017623, 3.41262416, 3.21657396, 3.21465048])

# %%
 def print_scores(scores):
     print("Scores:",scores)
     print("Mean:",scores.mean())
     print("Standard devaiation:",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores: [2.87180099 2.53708126 4.50680799 2.58460539 3.33792701 2.66122177
#  4.86017623 3.41262416 3.21657396 3.21465048]
# Mean: 3.3203469239453094
# Standard devaiation: 0.7483307430056666

# %% [markdown]
# ##  saving the model

# %%
from joblib import dump, load

# Assuming clf is already defined (the model you want to save)
#clf = RandomForestRegressor()  # Example, replace with your actual model

# Save the model
dump(model, 'Dragon.joblib')
# Out:
# ['Dragon.joblib']

# %% [markdown]
#  ## Testing the model on test data

# %%
X_test = strat_test_set.drop("MEDV", axis=1)  # Corrected 'axix' to 'axis'

# Remove the 'TEXTRM' extra column you added earlier (assuming it was a typo)
# If not, make sure this line is appropriate for your data


# Assuming 'MEDV' is the target variable, you can drop it from your features
Y_test = strat_test_set["MEDV"].copy()

x_test_prepared = my_pipeline.transform(X_test)

final_predictions = model.predict(x_test_prepared)  # Corrected 'mpdel' to 'model'

final_mse = mean_squared_error(Y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
#print(final_predictions,list(Y_test))
# Out:
# [24.948 12.062 25.175 22.081 18.782 15.15  19.949 14.561 31.714 41.459
#  19.34  11.406 24.363 25.967 19.543 11.211 31.586 14.367 23.419 18.514
#  19.515 17.578 17.103 22.346 18.401 31.187 15.989 32.886  9.102 33.189
#  24.488 21.382 22.501 10.86  21.269 11.125 43.342 24.529 23.156 41.907
#  24.119 29.27  20.24  21.402 18.79  33.37  44.18  20.484 20.184 21.549
#  21.737 14.473 21.442 14.813 24.776 32.759 41.984 28.666 19.331 20.991
#  46.664  9.652 19.001 24.741 15.074 32.797 19.72  17.823 19.282 34.35
#  26.337 22.802 21.779 22.521 34.603 12.72  15.66  20.021 20.891 21.453
#  22.576 21.153 14.39  22.939 20.797 20.986 13.461 21.329 21.438 23.283
#  18.735 26.934  7.413 26.957 19.506 29.969 19.941 30.873 14.744 27.165
# ...

# %%
final_rmse
# Out:
# 2.9814466007851492

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.23979304, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %% [markdown]
# ## Using the model

# %%
from joblib import dump,load
import numpy as np
model=load('Dragon.joblib')
features = np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
                   -0.23979304, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
                   -0.97491834, 0.41164221, -0.86091034]])

# Ensure that the input is a 2D array with shape (1, 13)
#input = np.reshape(input, (1, -1))

# Now you can make predictions
predictions = model.predict(features)
predictions
# Out:
# array([22.434])
